# %% [markdown]
# ## Covid Heatmap for Birbhum
# #### January 2022
# #### Rittik Mandal

# %%
import numpy as np
import pandas as pd
import folium as fl
from geopy.geocoders import Nominatim
from folium.plugins import MarkerCluster
from folium.plugins import HeatMap

# %%
num_case = ['7','26','19','17','12','13','61','76','3','12','23','31','3','1','38']
Area = ['Suri 1', 'Suri 2', 'Khoyrasole', 'Dubrajpur', 'Rajnagar','Md. Bazar','Sainthia','Bolpur','Labpur','Illambazar','Nanoor','Suri DH','Bolpur SDH','Suri MC','Bolpur MC']
Latitude = ['23.91189','23.901925','23.7883','23.7941','23.9451','23.9168','23.9487','23.663177','23.8161','23.6279','23.7040','23.915029','23.682966','23.912518','23.659777']
Longitude = ['87.524472','87.529706','87.2656','87.3746','87.3140','87.5170','87.6793','87.693706','87.7985','87.5421','87.8673','87.516755','87.688067','87.544219','87.703466']
data = {'Location': Area, 'Number of Cases': num_case,'Latitude':Latitude,'Longitude': Longitude}
df1 = pd.DataFrame(data)

# %%
print(df1)
# Out:
#       Location Number of Cases   Latitude  Longitude
# 0       Suri 1               7   23.91189  87.524472
# 1       Suri 2              26  23.901925  87.529706
# 2   Khoyrasole              19    23.7883    87.2656
# 3    Dubrajpur              17    23.7941    87.3746
# 4     Rajnagar              12    23.9451    87.3140
# 5    Md. Bazar              13    23.9168    87.5170
# 6     Sainthia              61    23.9487    87.6793
# 7       Bolpur              76  23.663177  87.693706
# 8       Labpur               3    23.8161    87.7985
# 9   Illambazar              12    23.6279    87.5421
# 10      Nanoor              23    23.7040    87.8673
# 11     Suri DH              31  23.915029  87.516755
# 12  Bolpur SDH               3  23.682966  87.688067
# 13     Suri MC               1  23.912518  87.544219
# 14   Bolpur MC              38  23.659777  87.703466

# %%
address =  'Bolpur'
geolocator = Nominatim(user_agent="cov_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
covid_map = fl.Map(location =[latitude,longitude], zoom_start = 10)

# %%
loc_lat = []
loc_long = []
for i in range(15):
    for j in range(int(df1['Number of Cases'][i])):
        loc_lat.append(df1['Latitude'][i])
        loc_long.append(df1['Longitude'][i])

# %%
loc_data = [(23.91189, 87.524472), (23.91189, 87.524472), (23.91189, 87.524472), (23.91189, 87.524472), (23.91189, 87.524472), (23.91189, 87.524472), (23.91189, 87.524472), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.901925, 87.529706), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7883, 87.2656), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.7941, 87.3746), (23.9451, 87.3140), (23.9451, 87.3140), (23.9451, 87.3140), (23.9451, 87.3140), (23.9451, 87.3140), (23.9451, 87.3140), (23.9451, 87.3140), (23.9451, 87.3140), (23.9451, 87.3140), (23.9451, 87.3140), (23.9451, 87.3140), (23.9451, 87.3140), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9168, 87.5170), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.9487, 87.6793), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.663177, 87.693706), (23.8161, 87.7985), (23.8161, 87.7985), (23.8161, 87.7985), (23.6279, 87.5421), (23.6279, 87.5421), (23.6279, 87.5421), (23.6279, 87.5421), (23.6279, 87.5421), (23.6279, 87.5421), (23.6279, 87.5421), (23.6279, 87.5421), (23.6279, 87.5421), (23.6279, 87.5421), (23.6279, 87.5421), (23.6279, 87.5421), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.7040, 87.8673), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.915029, 87.516755), (23.682966, 87.688067), (23.682966, 87.688067), (23.682966, 87.688067), (23.912518, 87.544219), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466), (23.659777, 87.703466)]

# %%
MarkerCluster(loc_data).add_to(covid_map)
HeatMap(loc_data).add_to(covid_map)

# %%
covid_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
